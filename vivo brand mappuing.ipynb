# %%
import pandas as pd
import numpy as np
import datetime
import os

# %%
import pandas as pd
import numpy as np
import os
import glob
import math
s1=input("give the brand input file")
s2=input("Give the csv file as input which have the list of sku whose brand mapping is required with column is SKU")
b=pd.read_csv(s1)
s=pd.read_csv(s2)
s["Brand"]=""
for brand in b["Brand"].str.lower():
    for i,sku in enumerate(s["SKU"].str.lower()):
        if brand in sku:
            s.loc[i,"Brand"]=brand
s.to_csv("brand mapped output.csv",index=False)
#C:\Users\HP\Downloads\brand.csv
#C:\Users\HP\Downloads\Sample data visibility 12_10_22 - papun_test.csv

# %%
data.head(5)
# Out:
#                                                _root         Brand  \
# 0  https://www.yelp.com/adredir?ad_business_id=uE...  Salons by JC
# 1  https://www.yelp.com/adredir?ad_business_id=uE...  Salons by JC
# 2  https://www.yelp.com/adredir?ad_business_id=uE...  Salons by JC
# 3  https://www.yelp.com/adredir?ad_business_id=uE...  Salons by JC
# 4  https://www.yelp.com/adredir?ad_business_id=uE...  Salons by JC
#
#     Product Rating Rating Count        Author                 date  \
# 0  4.5 star rating    9 reviews        Sam T.  2018-02-25 00:00:00
# 1  4.5 star rating    9 reviews    Barbara R.  2017-05-28 00:00:00
# 2  4.5 star rating    9 reviews  Alexander N.  2018-01-05 00:00:00
# 3  4.5 star rating    9 reviews      Betsy G.  2018-02-14 00:00:00
# 4  4.5 star rating    9 reviews     Alicia B.  2020-10-30 00:00:00
#
#                     Location  \
# 0                 Dallas, GA
# 1      Ridgewood, Queens, NY
# 2          San Francisco, CA
# 3  Getty Square, Yonkers, NY
# 4             Pittsburgh, PA
#
#                                               Review  Review Rating  \
# 0  Keisha gave a extraordinary first time experie...  5 star rating
# 1  Superb venue with over 40 suites that are rent...  5 star rating
# 2  I asked for a walk-in haircut and went into a ...  1 star rating
# 3  Salon by JC is most friendly place, the minute...  5 star rating
# 4  I came here to the Mona Cut on a Saturday morn...  5 star rating
#
#   Crawl Source Input Brand Input Data Crawl Completion Time(UTC) Original Date
# 0               yelp        test             2022-10-11 08:05:46     2/25/2018
# 1               yelp        test             2022-10-11 08:05:46     5/28/2017
# 2               yelp        test             2022-10-11 08:05:46      1/5/2018
# 3               yelp        test             2022-10-11 08:05:46     2/14/2018
# 4               yelp        test             2022-10-11 08:05:46    10/30/2020
